# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
def download_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data
def prepare_data(data, time_steps):
    x, y = [], []
    for i in range(len(data) - time_steps):
        x.append(data[i:(i + time_steps)])
        y.append(data[i + time_steps])
    return np.array(x), np.array(y)

np.random.seed(42)

stock_symbol = "AAPL"
start_date = "2022-01-01"
end_date = "2024-01-01"
stock_data = download_stock_data(stock_symbol, start_date, end_date)

closing_prices = stock_data['Close'].values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices)

time_steps = 60

x, y = prepare_data(closing_prices_scaled, time_steps)

split_ratio = 0.8
train_size = int(len(x) * split_ratio)
x_train, x_test = x[:train_size], x[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, epochs=100, batch_size=32)

predictions = model.predict(x_test)

predictions = scaler.inverse_transform(predictions)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 6s 64ms/step - loss: 0.0855
# Epoch 2/100
# 11/11 [==============================] - 1s 71ms/step - loss: 0.0188
# Epoch 3/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0121
# Epoch 4/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0094
# Epoch 5/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0076
# Epoch 6/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0067
# Epoch 7/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0062
# Epoch 8/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0058
# Epoch 9/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0054
# Epoch 10/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0055
# Epoch 11/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0050
# Epoch 12/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0050
# Epoch 13/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0047
# Epoch 14/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0046
# Epoch 15/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0045
# Epoch 16/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0045
# Epoch 17/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0043
# Epoch 18/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0042
# Epoch 19/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0041
# Epoch 20/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0042
# Epoch 21/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0040
# Epoch 22/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0039
# Epoch 23/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0041
# Epoch 24/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0043
# Epoch 25/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0053
# Epoch 26/100
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0041
# Epoch 27/100
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0039
# Epoch 28/100
# 11/11 [==============================] - 1s 67ms/step - loss: 0.0038
# Epoch 29/100
# 11/11 [==============================] - 1s 67ms/step - loss: 0.0039
# Epoch 30/100
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0037
# Epoch 31/100
# 11/11 [==============================] - 1s 46ms/step - loss: 0.0036
# Epoch 32/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0035
# Epoch 33/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0033
# Epoch 34/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0033
# Epoch 35/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0033
# Epoch 36/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0032
# Epoch 37/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0032
# Epoch 38/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0031
# Epoch 39/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0030
# Epoch 40/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0030
# Epoch 41/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0029
# Epoch 42/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0030
# Epoch 43/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0029
# Epoch 44/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0032
# Epoch 45/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0029
# Epoch 46/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0028
# Epoch 47/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0027
# Epoch 48/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0029
# Epoch 49/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0032
# Epoch 50/100
# 11/11 [==============================] - 1s 85ms/step - loss: 0.0029
# Epoch 51/100
# 11/11 [==============================] - 1s 96ms/step - loss: 0.0029
# Epoch 52/100
# 11/11 [==============================] - 1s 101ms/step - loss: 0.0027
# Epoch 53/100
# 11/11 [==============================] - 1s 106ms/step - loss: 0.0027
# Epoch 54/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.0026
# Epoch 55/100
# 11/11 [==============================] - 1s 95ms/step - loss: 0.0026
# Epoch 56/100
# 11/11 [==============================] - 1s 85ms/step - loss: 0.0025
# Epoch 57/100
# 11/11 [==============================] - 1s 84ms/step - loss: 0.0025
# Epoch 58/100
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0026
# Epoch 59/100
# 11/11 [==============================] - 1s 109ms/step - loss: 0.0026
# Epoch 60/100
# 11/11 [==============================] - 1s 116ms/step - loss: 0.0027
# Epoch 61/100
# 11/11 [==============================] - 1s 105ms/step - loss: 0.0025
# Epoch 62/100
# 11/11 [==============================] - 1s 79ms/step - loss: 0.0028
# Epoch 63/100
# 11/11 [==============================] - 1s 67ms/step - loss: 0.0026
# Epoch 64/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0024
# Epoch 65/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0024
# Epoch 66/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0027
# Epoch 67/100
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0026
# Epoch 68/100
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0023
# Epoch 69/100
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0023
# Epoch 70/100
# 11/11 [==============================] - 1s 70ms/step - loss: 0.0023
# Epoch 71/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0023
# Epoch 72/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0023
# Epoch 73/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0022
# Epoch 74/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0023
# Epoch 75/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0025
# Epoch 76/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0022
# Epoch 77/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0023
# Epoch 78/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0023
# Epoch 79/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0022
# Epoch 80/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0022
# Epoch 81/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0023
# Epoch 82/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0024
# Epoch 83/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0027
# Epoch 84/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0022
# Epoch 85/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0021
# Epoch 86/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0021
# Epoch 87/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0021
# Epoch 88/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0023
# Epoch 89/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0021
# Epoch 90/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0022
# Epoch 91/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0020
# Epoch 92/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0020
# Epoch 93/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0021
# Epoch 94/100
# 11/11 [==============================] - 1s 66ms/step - loss: 0.0021
# Epoch 95/100
# 11/11 [==============================] - 1s 70ms/step - loss: 0.0020
# Epoch 96/100
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0023
# Epoch 97/100
# 11/11 [==============================] - 1s 70ms/step - loss: 0.0023
# Epoch 98/100
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0021
# Epoch 99/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0022
# Epoch 100/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0021
# 3/3 [==============================] - 1s 14ms/step

# %%
plt.figure(figsize=(16, 8))
plt.plot(stock_data.index[-len(predictions):], predictions, label='Predicted Stock Price')
plt.plot(stock_data.index[-len(predictions):], scaler.inverse_transform(y_test.reshape(-1, 1)), label='Actual Stock Price')
plt.title(f'{stock_symbol} Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
